# %%
# Libraries required
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
try:
    # Change the current working Directory    
    os.chdir("/home/cyntsc/Proyectos/tesis-code/meta-xtrome-analysis/")
    print("Directory changed:", os.getcwd() )
except OSError:
    print("Can't change the Current Working Directory")
# Out:
# Directory changed: /home/cyntsc/Proyectos/tesis-code/meta-xtrome-analysis

# %%
  
# read csv file
df=pd.read_csv("results-data/wgcna/Athal_infected_selected_clusters.csv", sep=',', header=0)
df
# Out:
#     color  Genes     mergedColors   B12  B18   B24  Ch22  Ch40
# 0     Pos    818        chocolate  0.00  NaN  0.98   NaN   NaN
# 1     Pos    573       chocolate2  0.00  NaN   NaN  0.91   NaN
# 2     Pos    472           green3  0.00  NaN   NaN   NaN  0.95
# 3     Pos     99         lavender  0.00  NaN  0.79   NaN   NaN
# 4     Pos     72      dodgerblue1  0.96  NaN   NaN   NaN   NaN
# 5     Pos    189    mediumpurple1  0.00  NaN   NaN  0.85   NaN
# 6      PC    592      dodgerblue4   NaN  NaN  0.41  0.40 -0.89
# 7      PC    133      darkmagenta   NaN  NaN  0.57  0.59   NaN
# 8     Neg   1098         hotpink3 -0.75  NaN   NaN   NaN   NaN
# 9     Neg    368   palevioletred1   NaN  NaN   NaN   NaN -0.93
# 10    Neg    218          tomato2 -0.94  NaN   NaN   NaN   NaN
# 11    Neg    115          bisque4   NaN  NaN   NaN   NaN -0.75
# 12    Neg     39      deepskyblue   NaN -0.8   NaN   NaN   NaN
# 13    Neg    416            blue2 -0.79  NaN   NaN   NaN   NaN
# 14    Neg    261           brown2   NaN  NaN   NaN   NaN -0.85
# 15  Antag    597  darkolivegreen4  0.65  NaN   NaN   NaN -0.81
# 16  Antag    236            green   NaN  NaN -0.90  0.55   NaN
# 17  Antag    189             tan3 -0.77  NaN   NaN  0.71   NaN
# 18  Antag    160        indianred   NaN  NaN -0.81  0.54   NaN
# 19  Antag    540   lightsteelblue -0.70  NaN   NaN  0.75   NaN
# 20  Antag    196       lightblue2  0.84  NaN   NaN   NaN -0.61
# 21  Antag    135     antiquewhite -0.72  NaN -0.57   NaN  0.75

# %%
 
# using subplots() to draw vertical lines
fig, axes = plt.subplots()
  
# providing list of colors
line_colors = ['blue', 'cyan', 'green', 'red',
               'skyblue', 'brown', 'yellow',
               'black', 'grey', 'orange', 'maroon',
               'lightgreen']
  
axes.hlines(d['month_number'], xmin=0,
            xmax=d['total_profit'], colors=line_colors)
  
# drawing the markers (circle)
axes.plot(d['total_profit'], d['month_number'], "o")
axes.set_xlim(0)
  
# formatting and details
plt.xlabel('Profit')
plt.ylabel('Month')
plt.title('Total Profit')
plt.yticks(d['month_number'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d6af0822667b> in <module>
#       8                'lightgreen']
#       9
# ---> 10 axes.hlines(d['month_number'], xmin=0,
#      11             xmax=d['total_profit'], colors=line_colors)
#      12
#
# NameError: name 'd' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4e68fd38281f> in <module>
#       3
#       4 # The vertical plot is made using the vline function
# ----> 5 plt.vlines(x=x, ymin=0, ymax=y, color=my_color, alpha=0.4)
#       6 #plt.scatter(x, y, color=my_color, s=1, alpha=1)
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in vlines(x, ymin, ymax, colors, linestyles, label, data, **kwargs)
#    3262         x, ymin, ymax, colors=colors, linestyles=linestyles,
#    3263         label=label, **({"data": data} if data is not None else {}),
# -> 3264         **kwargs)
#    3265
#    3266
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1113         masked_verts[:, 0, 1] = ymin
#    1114         masked_verts[:, 1, 0] = x
# -> 1115         masked_verts[:, 1, 1] = ymax
#    1116
#    1117         lines = mcoll.LineCollection(masked_verts, colors=colors,
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in __setitem__(self, indx, value)
#    3335         if _mask is nomask:
#    3336             # Set the data, then the mask
# -> 3337             _data[indx] = dval
#    3338             if mval is not nomask:
#    3339                 _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (100) into shape (56)
