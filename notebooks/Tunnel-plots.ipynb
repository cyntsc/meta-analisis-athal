# %% [markdown]
# Gráfico del LnRR contra su error estandar. Si la distribución es simétrica alrededor del valor ponderado del RR seguramente no hay sesgo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# QUality Of Reporting Of Meta-analysis (QUORUM) Es una guía de 18 puntos (y un diagrama de flujo), que pueden utilizar autores, editores, revisores y lectores para la redacción de artículos sobre metaanálisis y para su valoración. Valoración de un Metaanálisis METAANÁLISIS <br>
# https://es.slideshare.net/juliocamposf/metanalisis-una-aproximacin-a-la-interpretacin-de-los-matanlisis

# %%
https://towardsdatascience.com/funnel-charts-with-python-1ef1a2b183ab
